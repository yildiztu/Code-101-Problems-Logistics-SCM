# %% [markdown]
# # Problem 37: The Equipment Selection Problem (RTG vs. RMG vs. Straddle)## Tier 7: The Human-AI Symbiotic Partnership (The Centaur Model)### Learning ObjectivesAfter completing this tier, you will be able to:- Design human-AI collaborative decision frameworks- Implement explainable AI for equipment selection- Build trust-based recommendation systems- Balance computational optimization with human expertise

# %%
import numpy as npimport pandas as pdimport matplotlib.pyplot as pltfrom dataclasses import dataclassfrom typing import List, Tuple, Dict, Optionalimport randomimport warningswarnings.filterwarnings('ignore')np.random.seed(42)print('Human-AI Symbiotic Partnership')print('Centaur Model for Equipment Selection')

# %% [markdown]
# ### Explainable Recommendation SystemAI provides recommendations with clear reasoning for human experts to review.

# %%
@dataclassclass EquipmentRecommendation:    primary_recommendation: str    confidence: float    key_factors: List[str]    trade_offs: Dict[str, Tuple[float, float]]    risk_factors: List[str]    human_override_points: List[str]def generate_recommendation(terminal_profile):    # AI analysis    factors = ['throughput', 'land_constraints', 'growth_forecast']        recommendation = EquipmentRecommendation(        primary_recommendation='Hybrid RTG-RMG mix',        confidence=0.87,        key_factors=[            'High throughput requires RMG efficiency',            'Limited land favors high-density stacking',            'Future automation roadmap aligned'        ],        trade_offs={            'capital_cost': (150e6, 180e6),            'operating_cost_annual': (12e6, 10e6),            'flexibility': (0.7, 0.5)        },        risk_factors=['Technology obsolescence', 'Maintenance complexity'],        human_override_points=['Local labor agreements', 'Environmental permits']    )    return recommendationrec = generate_recommendation({})print('AI Recommendation Generated:')print(f'  Primary: {rec.primary_recommendation}')print(f'  Confidence: {rec.confidence:.0%}')
