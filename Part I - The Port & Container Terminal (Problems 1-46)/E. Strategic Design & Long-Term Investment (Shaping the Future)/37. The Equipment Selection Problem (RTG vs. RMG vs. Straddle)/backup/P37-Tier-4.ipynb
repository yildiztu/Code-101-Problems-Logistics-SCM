# %% [markdown]
# # Problem 37: The Equipment Selection Problem (RTG vs. RMG vs. Straddle)## Tier 4: The AI/ML/RL Augmentation Method (Federated Learning)### Learning ObjectivesAfter completing this tier, you will be able to:- Understand federated learning for distributed equipment optimization- Implement privacy-preserving collaborative learning- Aggregate insights from multiple terminals- Apply transfer learning for equipment selection

# %%
import numpy as npimport pandas as pdimport matplotlib.pyplot as pltfrom dataclasses import dataclassfrom typing import List, Tuple, Dictimport randomimport warningswarnings.filterwarnings('ignore')np.random.seed(42)print('Federated Learning for Equipment Selection')print('Distributed Intelligence Across Terminals')

# %% [markdown]
# ### Terminal Data NodesMultiple terminals contribute to global model without sharing raw data.

# %%
@dataclassclass TerminalNode:    id: int    location: str    throughput: float  # TEU per year    equipment_mix: Dict[str, int]    performance_history: List[float]terminals = [    TerminalNode(1, 'Rotterdam', 8000000, {'RTG': 12, 'RMG': 8}, [0.85, 0.87, 0.89]),    TerminalNode(2, 'Singapore', 15000000, {'RTG': 20, 'RMG': 15}, [0.92, 0.93, 0.94]),    TerminalNode(3, 'Hamburg', 5000000, {'RTG': 8, 'Straddle': 12}, [0.82, 0.84, 0.85]),]print(f'Federated Network: {len(terminals)} terminals')for t in terminals:    print(f'  {t.location}: {t.throughput/1e6:.1f}M TEU')
